# %% [markdown]
# ## Project Visualization

# %%
#load libraries

import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
#Folder path

cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\zpap\\OneDrive - AholdDelhaize.com\\Personal elements\\04. Dimokritos_Files\\2nd SEMESTER\\Big Data Security and Visualization\\Visualiazation Project\\Data'

# %%
# Replace values from \ to /

path=cwd.replace("\\","/")
print(path)
# Out:
# C:/Users/zpap/OneDrive - AholdDelhaize.com/Personal elements/04. Dimokritos_Files/2nd SEMESTER/Big Data Security and Visualization/Visualiazation Project/Data

# %% [markdown]
# ## 2017

# %%
#Fill in the name of file and join it with path

filename2017Q1="/2017Q1-capitalbikeshare-tripdata.csv"
filename2017Q2="/2017Q2-capitalbikeshare-tripdata.csv"
filename2017Q3="/2017Q3-capitalbikeshare-tripdata.csv"
filename2017Q4="/2017Q4-capitalbikeshare-tripdata.csv"


traindata2017Q1=path+filename2017Q1
traindata2017Q2=path+filename2017Q2
traindata2017Q3=path+filename2017Q3
traindata2017Q4=path+filename2017Q4

# %%
train2017Q1 = pd.read_csv(traindata2017Q1,sep = ',', encoding="utf8")
train2017Q2 = pd.read_csv(traindata2017Q2,sep = ',', encoding="utf8")
train2017Q3 = pd.read_csv(traindata2017Q3,sep = ',', encoding="utf8")
train2017Q4 = pd.read_csv(traindata2017Q4,sep = ',', encoding="utf8")

# %%
#Add a new column that expresses the semi annual

train2017Q1['Semi Annual']="H1 2017"
train2017Q2['Semi Annual']="H1 2017"
train2017Q3['Semi Annual']="H2 2017"
train2017Q4['Semi Annual']="H2 2017"

# %%
#Create table

FY2017=pd.concat([train2017Q1,train2017Q2,train2017Q3,train2017Q4], ignore_index=True)
FY2017
# Out:
#          Duration           Start date             End date  \
# 0             221  2017-01-01 00:00:41  2017-01-01 00:04:23
# 1            1676  2017-01-01 00:06:53  2017-01-01 00:34:49
# 2            1356  2017-01-01 00:07:10  2017-01-01 00:29:47
# 3            1327  2017-01-01 00:07:22  2017-01-01 00:29:30
# 4            1636  2017-01-01 00:07:36  2017-01-01 00:34:52
# ...           ...                  ...                  ...
# 3757772       277  2017-12-31 23:43:17  2017-12-31 23:47:54
# 3757773       399  2017-12-31 23:51:55  2017-12-31 23:58:35
# 3757774       393  2017-12-31 23:55:19  2018-01-01 00:01:52
# 3757775      1319  2017-12-31 23:57:42  2018-01-01 00:19:42
# 3757776       266  2017-12-31 23:58:21  2018-01-01 00:02:48
#
#          Start station number                                Start station  \
# 0                       31634                           3rd & Tingey St SE
# 1                       31258                             Lincoln Memorial
# ...

# %%
FY2017.dtypes
# Out:
# Duration                 int64
# Start date              object
# End date                object
# Start station number     int64
# Start station           object
# End station number       int64
# End station             object
# Bike number             object
# Member type             object
# Semi Annual             object
# dtype: object

# %%
FY2017.to_csv('FY2017.csv',";", index = False)

# %% [markdown]
# ## 2018

# %%
#Fill in the name of file and join it with path

filename201801="/201801_capitalbikeshare_tripdata.csv"
filename201802="/201802-capitalbikeshare-tripdata.csv"
filename201803="/201803-capitalbikeshare-tripdata.csv"
filename201804="/201804-capitalbikeshare-tripdata.csv"
filename201805="/201805-capitalbikeshare-tripdata.csv"
filename201806="/201806-capitalbikeshare-tripdata.csv"
filename201807="/201807-capitalbikeshare-tripdata.csv"
filename201808="/201808-capitalbikeshare-tripdata.csv"
filename201809="/201809-capitalbikeshare-tripdata.csv"
filename201810="/201810-capitalbikeshare-tripdata.csv"
filename201811="/201811-capitalbikeshare-tripdata.csv"
filename201812="/201812-capitalbikeshare-tripdata.csv"

traindata201801=path+filename201801
traindata201802=path+filename201802
traindata201803=path+filename201803
traindata201804=path+filename201804
traindata201805=path+filename201805
traindata201806=path+filename201806
traindata201807=path+filename201807
traindata201808=path+filename201808
traindata201809=path+filename201809
traindata201810=path+filename201810
traindata201811=path+filename201811
traindata201812=path+filename201812

# %%
train201801 = pd.read_csv(traindata201801,sep = ',', encoding="utf8")
train201802 = pd.read_csv(traindata201802,sep = ',', encoding="utf8")
train201803 = pd.read_csv(traindata201803,sep = ',', encoding="utf8")
train201804 = pd.read_csv(traindata201804,sep = ',', encoding="utf8")
train201805 = pd.read_csv(traindata201805,sep = ',', encoding="utf8")
train201806 = pd.read_csv(traindata201806,sep = ',', encoding="utf8")
train201807 = pd.read_csv(traindata201807,sep = ',', encoding="utf8")
train201808 = pd.read_csv(traindata201808,sep = ',', encoding="utf8")
train201809 = pd.read_csv(traindata201809,sep = ',', encoding="utf8")
train201810 = pd.read_csv(traindata201810,sep = ',', encoding="utf8")
train201811 = pd.read_csv(traindata201811,sep = ',', encoding="utf8")
train201812 = pd.read_csv(traindata201812,sep = ',', encoding="utf8")

# %%
#Add a new column that expresses the semi annual

train201801['Semi Annual']="H1 2018"
train201802['Semi Annual']="H1 2018"
train201803['Semi Annual']="H1 2018"
train201804['Semi Annual']="H1 2018"
train201805['Semi Annual']="H1 2018"
train201806['Semi Annual']="H1 2018"
train201807['Semi Annual']="H2 2018"
train201808['Semi Annual']="H2 2018"
train201809['Semi Annual']="H2 2018"
train201810['Semi Annual']="H2 2018"
train201811['Semi Annual']="H2 2018"
train201812['Semi Annual']="H2 2018"
train201802
# Out:
#         Duration           Start date             End date  \
# 0            892  2018-02-01 00:01:29  2018-02-01 00:16:21
# 1            501  2018-02-01 00:04:19  2018-02-01 00:12:40
# 2            788  2018-02-01 00:05:03  2018-02-01 00:18:12
# 3            406  2018-02-01 00:18:11  2018-02-01 00:24:57
# 4            161  2018-02-01 00:18:11  2018-02-01 00:20:53
# ...          ...                  ...                  ...
# 182373       418  2018-02-28 23:57:06  2018-03-01 00:04:04
# 182374       565  2018-02-28 23:57:10  2018-03-01 00:06:35
# 182375       651  2018-02-28 23:58:18  2018-03-01 00:09:10
# 182376       779  2018-02-28 23:59:45  2018-03-01 00:12:44
# 182377      1972  2018-02-28 23:59:53  2018-03-01 00:32:46
#
#         Start station number                          Start station  \
# 0                      31312                Wisconsin Ave & O St NW
# 1                      31089  Court House Metro / 15th & N Uhle St
# ...

# %%
FY2018=pd.concat([train201801,train201802,train201803,train201804,train201805,train201806,train201807,train201808,train201809,train201810,train201811,train201812], ignore_index=True)
FY2018
# Out:
#          Duration           Start date             End date  \
# 0             552  2018-01-01 00:05:06  2018-01-01 00:14:18
# 1            1282  2018-01-01 00:14:30  2018-01-01 00:35:53
# 2            1265  2018-01-01 00:14:53  2018-01-01 00:35:58
# 3             578  2018-01-01 00:15:31  2018-01-01 00:25:09
# 4             372  2018-01-01 00:18:02  2018-01-01 00:24:15
# ...           ...                  ...                  ...
# 3542679      3313  2018-12-31 23:37:22  2019-01-01 00:32:36
# 3542680       888  2018-12-31 23:42:18  2018-12-31 23:57:07
# 3542681      2332  2018-12-31 23:44:23  2019-01-01 00:23:16
# 3542682       307  2018-12-31 23:52:42  2018-12-31 23:57:50
# 3542683      1062  2018-12-31 23:54:09  2019-01-01 00:11:52
#
#          Start station number                  Start station  \
# 0                       31104    Adams Mill & Columbia Rd NW
# 1                       31321  15th St & Constitution Ave NW
# ...

# %%
FY2018.dtypes
# Out:
# Duration                 int64
# Start date              object
# End date                object
# Start station number     int64
# Start station           object
# End station number       int64
# End station             object
# Bike number             object
# Member type             object
# Semi Annual             object
# dtype: object

# %%
FY2018.to_csv('FY2018.csv', ";",index = False)

# %% [markdown]
# ## 2019

# %%
#Fill in the name of file and join it with path

filename201901="/201901-capitalbikeshare-tripdata.csv"
filename201902="/201902-capitalbikeshare-tripdata.csv"
filename201903="/201903-capitalbikeshare-tripdata.csv"
filename201904="/201904-capitalbikeshare-tripdata.csv"
filename201905="/201905-capitalbikeshare-tripdata.csv"
filename201906="/201906-capitalbikeshare-tripdata.csv"
filename201907="/201907-capitalbikeshare-tripdata.csv"
filename201908="/201908-capitalbikeshare-tripdata.csv"
filename201909="/201909-capitalbikeshare-tripdata.csv"
filename201910="/201910-capitalbikeshare-tripdata.csv"
filename201911="/201911-capitalbikeshare-tripdata.csv"
filename201912="/201912-capitalbikeshare-tripdata.csv"

traindata201901=path+filename201901
traindata201902=path+filename201902
traindata201903=path+filename201903
traindata201904=path+filename201904
traindata201905=path+filename201905
traindata201906=path+filename201906
traindata201907=path+filename201907
traindata201908=path+filename201908
traindata201909=path+filename201909
traindata201910=path+filename201910
traindata201911=path+filename201911
traindata201912=path+filename201912

# %%
train201901 = pd.read_csv(traindata201901,sep = ',', encoding="utf8")
train201902 = pd.read_csv(traindata201902,sep = ',', encoding="utf8")
train201903 = pd.read_csv(traindata201903,sep = ',', encoding="utf8")
train201904 = pd.read_csv(traindata201904,sep = ',', encoding="utf8")
train201905 = pd.read_csv(traindata201905,sep = ',', encoding="utf8")
train201906 = pd.read_csv(traindata201906,sep = ',', encoding="utf8")
train201907 = pd.read_csv(traindata201907,sep = ',', encoding="utf8")
train201908 = pd.read_csv(traindata201908,sep = ',', encoding="utf8")
train201909 = pd.read_csv(traindata201909,sep = ',', encoding="utf8")
train201910 = pd.read_csv(traindata201910,sep = ',', encoding="utf8")
train201911 = pd.read_csv(traindata201911,sep = ',', encoding="utf8")
train201912 = pd.read_csv(traindata201912,sep = ',', encoding="utf8")

# %%
#Add a new column that expresses the semi annual

train201901['Semi Annual']="H1 2019"
train201902['Semi Annual']="H1 2019"
train201903['Semi Annual']="H1 2019"
train201904['Semi Annual']="H1 2019"
train201905['Semi Annual']="H1 2019"
train201906['Semi Annual']="H1 2019"
train201907['Semi Annual']="H2 2019"
train201908['Semi Annual']="H2 2019"
train201909['Semi Annual']="H2 2019"
train201910['Semi Annual']="H2 2019"
train201911['Semi Annual']="H2 2019"
train201912['Semi Annual']="H2 2019"

# %%
FY2019=pd.concat([train201901,train201902,train201903,train201904,train201905,train201906,train201907,train201908,train201909,train201910,train201911,train201912], ignore_index=True)
FY2019
# Out:
#          Duration           Start date             End date  \
# 0             230  2019-01-01 00:04:48  2019-01-01 00:08:39
# 1            1549  2019-01-01 00:06:37  2019-01-01 00:32:27
# 2             177  2019-01-01 00:08:46  2019-01-01 00:11:44
# 3             228  2019-01-01 00:08:47  2019-01-01 00:12:35
# 4            1300  2019-01-01 00:12:29  2019-01-01 00:34:10
# ...           ...                  ...                  ...
# 3398412       130  2019-12-31 23:57:36  2019-12-31 23:59:46
# 3398413       664  2019-12-31 23:57:47  2020-01-01 00:08:51
# 3398414       389  2019-12-31 23:59:37  2020-01-01 00:06:06
# 3398415       962  2019-12-31 23:59:38  2020-01-01 00:15:40
# 3398416       183  2019-12-31 23:59:55  2020-01-01 00:02:58
#
#          Start station number                           Start station  \
# 0                       31203              14th & Rhode Island Ave NW
# 1                       31321           15th St & Constitution Ave NW
# ...

# %%
FY2019.dtypes
# Out:
# Duration                 int64
# Start date              object
# End date                object
# Start station number     int64
# Start station           object
# End station number       int64
# End station             object
# Bike number             object
# Member type             object
# Semi Annual             object
# dtype: object

# %%
FY2019.to_csv('FY2019.csv',";", index = False)

# %%
Allyears=pd.concat([FY2017,FY2018,FY2019], ignore_index=True)
Allyears
# Out:
#           Duration           Start date             End date  \
# 0              221  2017-01-01 00:00:41  2017-01-01 00:04:23
# 1             1676  2017-01-01 00:06:53  2017-01-01 00:34:49
# 2             1356  2017-01-01 00:07:10  2017-01-01 00:29:47
# 3             1327  2017-01-01 00:07:22  2017-01-01 00:29:30
# 4             1636  2017-01-01 00:07:36  2017-01-01 00:34:52
# ...            ...                  ...                  ...
# 10698873       130  2019-12-31 23:57:36  2019-12-31 23:59:46
# 10698874       664  2019-12-31 23:57:47  2020-01-01 00:08:51
# 10698875       389  2019-12-31 23:59:37  2020-01-01 00:06:06
# 10698876       962  2019-12-31 23:59:38  2020-01-01 00:15:40
# 10698877       183  2019-12-31 23:59:55  2020-01-01 00:02:58
#
#           Start station number                                Start station  \
# 0                        31634                           3rd & Tingey St SE
# 1                        31258                             Lincoln Memorial
# ...

# %%
Allyears.to_csv('Allyears.csv',";", index = False)

# %% [markdown]
# ## 2020

# %%
#Fill in the name of file and join it with path

filename202001="/202001-capitalbikeshare-tripdata.csv"
filename202002="/202002-capitalbikeshare-tripdata.csv"
filename202003="/202003-capitalbikeshare-tripdata.csv"
filename202004="/202004-capitalbikeshare-tripdata.csv"
filename202005="/202005-capitalbikeshare-tripdata.csv"
filename202006="/202006-capitalbikeshare-tripdata.csv"
filename202007="/202007-capitalbikeshare-tripdata.csv"
filename202008="/202008-capitalbikeshare-tripdata.csv"
filename202009="/202009-capitalbikeshare-tripdata.csv"
filename202010="/202010-capitalbikeshare-tripdata.csv"
filename202011="/202011-capitalbikeshare-tripdata.csv"
filename202012="/202012-capitalbikeshare-tripdata.csv"

traindata202001=path+filename202001
traindata202002=path+filename202002
traindata202003=path+filename202003
traindata202004=path+filename202004
traindata202005=path+filename202005
traindata202006=path+filename202006
traindata202007=path+filename202007
traindata202008=path+filename202008
traindata202009=path+filename202009
traindata202010=path+filename202010
traindata202011=path+filename202011
traindata202012=path+filename202012

# %%
train202001 = pd.read_csv(traindata202001,sep = ',', encoding="utf8")
train202002 = pd.read_csv(traindata202002,sep = ',', encoding="utf8")
train202003 = pd.read_csv(traindata202003,sep = ',', encoding="utf8")
train202004 = pd.read_csv(traindata202004,sep = ',', encoding="utf8")
train202005 = pd.read_csv(traindata202005,sep = ',', encoding="utf8")
train202006 = pd.read_csv(traindata202006,sep = ',', encoding="utf8")
train202007 = pd.read_csv(traindata202007,sep = ',', encoding="utf8")
train202008 = pd.read_csv(traindata202008,sep = ',', encoding="utf8")
train202009 = pd.read_csv(traindata202009,sep = ',', encoding="utf8")
train202010 = pd.read_csv(traindata202010,sep = ',', encoding="utf8")
train202011 = pd.read_csv(traindata202011,sep = ',', encoding="utf8")
train202012 = pd.read_csv(traindata202012,sep = ',', encoding="utf8")

# %%
#Add a new column that expresses the semi annual

train202001['Semi Annual']="H1 2020"
train202002['Semi Annual']="H1 2020"
train202003['Semi Annual']="H1 2020"
train202004['Semi Annual']="H1 2020"
train202005['Semi Annual']="H1 2020"
train202006['Semi Annual']="H1 2020"
train202007['Semi Annual']="H2 2020"
train202008['Semi Annual']="H2 2020"
train202009['Semi Annual']="H2 2020"
train202010['Semi Annual']="H2 2020"
train202011['Semi Annual']="H2 2020"
train202012['Semi Annual']="H2 2020"

# %%
FY2020=pd.concat([train202001,train202002,train202003,train202004,train202005,train202006,train202007,train202008,train202009,train202010,train202011,train202012], ignore_index=True)
FY2020
# Out:
#          Duration           Start date             End date  \
# 0           506.0  2020-01-01 00:00:59  2020-01-01 00:09:26
# 1          1050.0  2020-01-01 00:01:16  2020-01-01 00:18:47
# 2          1687.0  2020-01-01 00:02:42  2020-01-01 00:30:50
# 3           182.0  2020-01-01 00:02:44  2020-01-01 00:05:47
# 4          1002.0  2020-01-01 00:06:12  2020-01-01 00:22:54
# ...           ...                  ...                  ...
# 2216909       NaN                  NaN                  NaN
# 2216910       NaN                  NaN                  NaN
# 2216911       NaN                  NaN                  NaN
# 2216912       NaN                  NaN                  NaN
# 2216913       NaN                  NaN                  NaN
#
#          Start station number  \
# 0                     31623.0
# 1                     31613.0
# 2                     31218.0
# 3                     31627.0
# 4                     31247.0
# ...                       ...
# ...

# %%
FY2020.dtypes
# Out:
# Duration                float64
# Start date               object
# End date                 object
# Start station number    float64
# Start station            object
# End station number      float64
# End station              object
# Bike number              object
# Member type              object
# Semi Annual              object
# ride_id                  object
# rideable_type            object
# started_at               object
# ended_at                 object
# start_station_name       object
# start_station_id        float64
# end_station_name         object
# end_station_id          float64
# start_lat               float64
# start_lng               float64
# end_lat                 float64
# end_lng                 float64
# member_casual            object
# dtype: object

# %%
FY2020.to_csv('FY2020.csv',";", index = False)

# %% [markdown]
# ## 2021

# %%
#Fill in the name of file and join it with path

filename202101="/202101-capitalbikeshare-tripdata.csv"
filename202102="/202102-capitalbikeshare-tripdata.csv"
filename202103="/202103-capitalbikeshare-tripdata.csv"
filename202104="/202104-capitalbikeshare-tripdata.csv"
filename202105="/202105-capitalbikeshare-tripdata.csv"
filename202106="/202106-capitalbikeshare-tripdata.csv"
filename202107="/202107-capitalbikeshare-tripdata.csv"
filename202108="/202108-capitalbikeshare-tripdata.csv"
filename202109="/202109-capitalbikeshare-tripdata.csv"
filename202110="/202110-capitalbikeshare-tripdata.csv"
filename202111="/202111-capitalbikeshare-tripdata.csv"
filename202112="/202112-capitalbikeshare-tripdata.csv"

traindata202101=path+filename202101
traindata202102=path+filename202102
traindata202103=path+filename202103
traindata202104=path+filename202104
traindata202105=path+filename202105
traindata202106=path+filename202106
traindata202107=path+filename202107
traindata202108=path+filename202108
traindata202109=path+filename202109
traindata202110=path+filename202110
traindata202111=path+filename202111
traindata202112=path+filename202112

# %%
train202101 = pd.read_csv(traindata202101,sep = ',', encoding="utf8")
train202102 = pd.read_csv(traindata202102,sep = ',', encoding="utf8")
train202103 = pd.read_csv(traindata202103,sep = ',', encoding="utf8")
train202104 = pd.read_csv(traindata202104,sep = ',', encoding="utf8")
train202105 = pd.read_csv(traindata202105,sep = ',', encoding="utf8")
train202106 = pd.read_csv(traindata202106,sep = ',', encoding="utf8")
train202107 = pd.read_csv(traindata202107,sep = ',', encoding="utf8")
train202108 = pd.read_csv(traindata202108,sep = ',', encoding="utf8")
train202109 = pd.read_csv(traindata202109,sep = ',', encoding="utf8")
train202110 = pd.read_csv(traindata202110,sep = ',', encoding="utf8")
train202111 = pd.read_csv(traindata202111,sep = ',', encoding="utf8")
train202112 = pd.read_csv(traindata202112,sep = ',', encoding="utf8")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Add a new column that expresses the semi annual

train202101['Semi Annual']="H1 2021"
train202102['Semi Annual']="H1 2021"
train202103['Semi Annual']="H1 2021"
train202104['Semi Annual']="H1 2021"
train202105['Semi Annual']="H1 2021"
train202106['Semi Annual']="H1 2021"
train202107['Semi Annual']="H2 2021"
train202108['Semi Annual']="H2 2021"
train202109['Semi Annual']="H2 2021"
train202110['Semi Annual']="H2 2021"
train202111['Semi Annual']="H2 2021"
train202112['Semi Annual']="H2 2021"

# %%
FY2021=pd.concat([train202101,train202102,train202103,train202104,train202105,train202106,train202107,train202108,train202109,train202110,train202111,train202112], ignore_index=True)
FY2021
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        13A48BD20CC3DD85   classic_bike  2021-01-08 17:58:48
# 1        CA68C580B32EEE66  electric_bike  2021-01-08 22:05:51
# 2        5A925307814D5C2B   classic_bike  2021-01-21 17:20:31
# 3        B6B2DB54A2B233EE   classic_bike  2021-01-28 10:06:30
# 4        921A142D5C8A9759   classic_bike  2021-01-11 12:09:45
# ...                   ...            ...                  ...
# 2749876  8C999F60CA429723   classic_bike  2021-12-15 18:26:44
# 2749877  CA9B6486BDC1D25A  electric_bike  2021-12-15 00:45:55
# 2749878  95957793A0807E8B   classic_bike  2021-12-06 14:17:45
# 2749879  99DA9A8F72185C79    docked_bike  2021-12-29 14:59:01
# 2749880  561DB870CDB1A6B0   classic_bike  2021-12-12 14:45:39
#
#                     ended_at             start_station_name start_station_id  \
# 0        2021-01-08 18:25:23   Connecticut Ave & Yuma St NW          31318.0
# ...

# %%
FY2021.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# Semi Annual            object
# dtype: object

# %%
FY2021.to_csv('FY2021.csv',";", index = False)
